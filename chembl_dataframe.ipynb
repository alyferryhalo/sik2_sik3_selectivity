# %%
import pandas as pd

# %%
SIK2 = pd.read_csv('chembl_SIK2.csv', sep=';')
SIK3 = pd.read_csv('chembl_SIK3.csv', sep=';')

# %%
SIK2
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase Molecular Weight  \
# 0          CHEMBL365248     GW810372X                   0           402.34
# 1         CHEMBL1909374     GW709042A                   0           585.95
# 2         CHEMBL1794059     GW275616X                   0           315.35
# 3         CHEMBL4878072           NaN                   0           449.56
# 4         CHEMBL1909407           NaN                   0           374.85
# ...                 ...           ...                 ...              ...
# 1421      CHEMBL3577885   PF-05105679                   1           428.46
# 1422      CHEMBL4540759       BI 0054                   0           382.39
# 1423      CHEMBL4522773       BAY-827                   0           385.86
# 1424      CHEMBL4580220      BAY-3827                   0           468.54
# 1425      CHEMBL4518342     THPP-1-NC                   0           493.45
#
#      #RO5 Violations AlogP                 Compound Key  \
# ...

# %%
SIK3
# Out:
#     Molecule ChEMBL ID Molecule Name  Molecule Max Phase Molecular Weight  \
# 0        CHEMBL4870304           NaN                   0           499.53
# 1        CHEMBL2348350           NaN                   0           438.56
# 2         CHEMBL105442       CI-1040                   2           478.66
# 3          CHEMBL31965    CANERTINIB                   3           485.95
# 4          CHEMBL24828    VANDETANIB                   4           475.36
# ..                 ...           ...                 ...              ...
# 535      CHEMBL4537673       BAY-985                   0           553.59
# 536       CHEMBL111612       ABT-546                   0           532.72
# 537       CHEMBL332794      A-192621                   0           558.68
# 538      CHEMBL4630642       BAY-974                   0           422.49
# 539      CHEMBL4518342     THPP-1-NC                   0           493.45
#
#     #RO5 Violations AlogP Compound Key  \
# ...

# %%
SIK2.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
SIK3.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
SIK2['Standard Type'].unique()
# Out:
# array(['Inhibition', 'Activity', 'Kd', 'Residual activity', 'Ki', 'IC50',
#        '% Control', '% Ctrl', '% residual kinase activity', 'INH',
#        '% Residual activity with Skepinone-L'], dtype=object)

# %%
SIK3['Standard Type'].unique()
# Out:
# array(['Activity', 'Kd', 'Inhibition', 'IC50', '% Control',
#        '% residual kinase activity', '% Ctrl'], dtype=object)

# %%
SIK2_selected_column = SIK2[['Molecule ChEMBL ID', 'Smiles', 'Standard Type', 'Standard Relation', 
                             'Standard Value', 'Standard Units', 'Target Name']]

# %%
SIK3_selected_column = SIK3[['Molecule ChEMBL ID', 'Smiles', 'Standard Type', 'Standard Relation', 
                             'Standard Value', 'Standard Units', 'Target Name']]

# %%
SIK2_IC50 = SIK2_selected_column.loc[SIK2_selected_column['Standard Type'] == 'IC50']

# %%
SIK3_IC50 = SIK3_selected_column.loc[SIK3_selected_column['Standard Type'] == 'IC50']

# %%
SIK_chembl = SIK2_IC50.append(SIK3_IC50, ignore_index=True)
# Out:
# /var/folders/7f/r6y7pww15x53z42m3h5vt12r0000gn/T/ipykernel_15326/543114233.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   SIK_chembl = SIK2_IC50.append(SIK3_IC50, ignore_index=True)

# %%
SIK_chembl
# Out:
#    Molecule ChEMBL ID                                             Smiles  \
# 0       CHEMBL3780091  N[C@H]1CC[C@@H](Nc2cc[nH]c(=O)c2-c2nc3ccccc3[n...
# 1       CHEMBL4634634  C[C@@H]1C[C@H]1C(=O)N1CCN(c2cnc(C#N)c(-c3cnn(C...
# 2       CHEMBL3326006  CCCCNc1ncc2c(-c3ccc(CN4CCN(C)CC4)cc3)cn([C@H]3...
# 3       CHEMBL3745885  Cn1c(=O)c(S(=O)(=O)c2ccc(F)cc2F)cc2cnc(Nc3ccc4...
# 4       CHEMBL3770443  CNc1ncc2cc(-c3ccc(-c4cccc(C)n4)cc3Cl)c(=O)n(C[...
# ..                ...                                                ...
# 65      CHEMBL4865214  Cc1nc(Nc2ncc(C(=O)Nc3ncccc3C)s2)cc(N2CCN(CCO)C...
# 66      CHEMBL4850733  Cc1nc(Nc2ncc(C(=O)Nc3c(C)noc3C)s2)cc(N2CCN(CCO...
# 67      CHEMBL4865466  CC(=O)N1CCN(c2cc(Nc3ncc(C(=O)Nc4c(C)csc4Cl)s3)...
# 68      CHEMBL4859689  Cc1nc(Nc2ncc(C(=O)Nc3c(C)nn(C)c3C)s2)cc(N2CCN(...
# 69      CHEMBL4856384  Cc1nc(Nc2ncc(C(=O)NC3CN4CCC3CC4)s2)cc(NN2CCN(C...
#
#    Standard Type Standard Relation  Standard Value Standard Units  \
# ...

# %%
SIK_chembl.to_csv('SIK_chembl.csv', sep='\t')
